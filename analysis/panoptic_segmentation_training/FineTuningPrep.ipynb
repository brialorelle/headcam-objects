# %% [markdown]
# # File Overview

# %% [markdown]
# Dictionary structures included in this notebook:
#
# annotations[id]
#   * list of dictionaries containing:
#     * 'class_id' : ID associated with annotation class
#     * 'height' : height
#     * 'left': (start pixel of bbox on left side)
#     * 'top': (start pixel of bbox on top)
#     * 'width': width
#
# images[id]
#   * 'url': image_url
#   * 'image_size'
#     * list of one dictionary containing:
#       * 'depth': all
#       * 'height': height of image
#       * 'width': width of image
#
# classes[classID]
#   * category/label name

# %% [markdown]
# # Import libraries and mount Drive

# %%
# !pip install xmltodict
# Out:
# Requirement already satisfied: xmltodict in /opt/anaconda3/lib/python3.8/site-packages (0.12.0)

# %%
import json
import xmltodict
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as patches
import requests
from io import BytesIO
from PIL import Image
import pandas as pd
import pickle
import urllib
import os
import gzip
from datetime import datetime,timezone,timedelta

# %%
# uncomment if using colab
# from google.colab import drive
# drive.mount('/content/drive')
# Out:
# /content/drive/My Drive/LangCog

# %% [markdown]
# # Load object labels

# %%
def loadObjList(txtFileLink):
    # define an empty list
    words = []
    
    # open file and read the content into a list
    txtFile = urllib.request.urlopen(txtFileLink)
    for line in txtFile:
      decoded_line = line.decode("utf-8")

      # remove linebreak which is the last character of the string
      currentWord = decoded_line[:-1]

      # add item to the list
      words.append(currentWord)

    words = list(set(words))
    words.sort() #alphabetize
    return words

# %%
categories = {}       # dictionary mapping labels to ids
catId = 1
for cat in labels:
  categories[cat] = catId
  catId+=1

# %%
categories
# Out:
# {'bag': 1,
#  'ball': 2,
#  'basket': 3,
#  'block': 4,
#  'book': 5,
#  'bottle': 6,
#  'box': 7,
#  'can': 8,
#  'cat': 9,
#  'computer': 10,
#  'crayon': 11,
#  'cup': 12,
#  'door': 13,
#  'drum': 14,
#  'fruit': 15,
#  'guitar': 16,
#  'ipad': 17,
#  'marker': 18,
#  'other food': 19,
#  'other toy': 20,
#  'paper': 21,
#  'phone': 22,
#  'photograph': 23,
#  'piano': 24,
#  'plant': 25,
#  'plate': 26,
#  'play dough': 27,
#  'play gym': 28,
#  'puzzle': 29,
#  'remote': 30,
#  'shoe': 31,
#  'sippy cup': 32,
#  'spoon': 33,
#  'stuffed animal': 34,
#  'table': 35,
#  'toilet': 36,
#  'xylophone': 37}

# %% [markdown]
# So now, we have a list of labels from the object list and a mapping of category names to ids (this is for putting the data in COCO JSON format)

# %% [markdown]
# # Load JSONs

# %% [markdown]
# Install the manifest-tool to use for loading manifest file

# %%
manifestFileName = "https://raw.githubusercontent.com/brialorelle/headcam-objects/master/data/annotations/broad_category_segmentations/24K/output.manifest"

manifestFile = requests.get(manifestFileName)

manifestString = "[" + manifestFile.text.replace("}\n{", "},\n{") + "]"

data = json.loads(manifestString)

# %%
for frame in data:
  print(frame)
# Out:
# {'source-ref': 's3://interestingsaycam/images/11125-A_20150127_2814_01.mp4-38000.jpg', 'saycam-objects-3-workers-test': {'image_size': [{'width': 640, 'height': 480, 'depth': 3}], 'annotations': [{'class_id': 5, 'top': 38, 'left': 278, 'height': 148, 'width': 53}, {'class_id': 5, 'top': 176, 'left': 293, 'height': 28, 'width': 28}, {'class_id': 5, 'top': 166, 'left': 273, 'height': 23, 'width': 26}, {'class_id': 5, 'top': 0, 'left': 260, 'height': 60, 'width': 105}, {'class_id': 6, 'top': 2.6666666666666856, 'left': 264, 'height': 201.66666666666663, 'width': 84.66666666666669}, {'class_id': 0, 'top': 136.33333333333331, 'left': 477.6666666666667, 'height': 343, 'width': 161.66666666666669}, {'class_id': 13, 'top': 106, 'left': 5, 'height': 369, 'width': 556}, {'class_id': 12, 'top': 173, 'left': 492, 'height': 301, 'width': 148}]}, 'saycam-objects-3-workers-test-metadata': {'objects': [{'confidence': 0.09}, {'confidence': 0.09}, {'confidence': 0.09}, {'confidence': 0.09}, {'confidence': 0.4}, {'confidence': 0.47}, {'confidence': 0.09}, {'confidence': 0.09}], 'class-map': {'5': 'Clothing', '6': 'Person', '0': 'Furniture', '13': 'Building', '12': 'Other small object'}, 'type': 'groundtruth/object-detection', 'human-annotated': 'yes', 'creation-date': '2020-11-19T00:39:46.794986', 'job-name': 'labeling-job/saycam-objects-3-workers-test'}}
# {'source-ref': 's3://interestingsaycam/images/11825-A_20150426_3113_01.mp4-17740.jpg', 'saycam-objects-3-workers-test': {'image_size': [{'width': 640, 'height': 480, 'depth': 3}], 'annotations': [{'class_id': 12, 'top': 105, 'left': 3.5, 'height': 371.5, 'width': 330.5}, {'class_id': 12, 'top': 314, 'left': 63, 'height': 93, 'width': 100}, {'class_id': 13, 'top': 2, 'left': 2, 'height': 477, 'width': 636}]}, 'saycam-objects-3-workers-test-metadata': {'objects': [{'confidence': 0.28}, {'confidence': 0.09}, {'confidence': 0.09}], 'class-map': {'12': 'Other small object', '13': 'Building'}, 'type': 'groundtruth/object-detection', 'human-annotated': 'yes', 'creation-date': '2020-11-19T00:37:42.540193', 'job-name': 'labeling-job/saycam-objects-3-workers-test'}}
# {'source-ref': 's3://interestingsaycam/images/14077-S_20130808_0922_03.AVI.mp4-14875.jpg', 'saycam-objects-3-workers-test': {'image_size': [{'width': 640, 'height': 480, 'depth': 3}], 'annotations': [{'class_id': 0, 'top': 308.66666666666663, 'left': 24, 'height': 131.33333333333334, 'width': 491.66666666666663}, {'class_id': 6, 'top': 2, 'left': 177.66666666666666, 'height': 374, 'width': 404}, {'class_id': 8, 'top': 296, 'left': 196, 'height': 68, 'width': 50}, {'class_id': 9, 'top': 359, 'left': 16, 'height': 121, 'width': 624}, {'class_id': 12, 'top': 230, 'left': 114, 'height': 87, 'width': 61}]}, 'saycam-objects-3-workers-test-metadata': {'objects': [{'confidence': 0.28}, {'confidence': 0.47}, {'confidence': 0.09}, {'confidence': 0.09}, {'confidence': 0.09}], 'class-map': {'0': 'Furniture', '6': 'Person', '8': 'Food', '9': 'Utensils', '12': 'Other small object'}, 'type': 'groundtruth/object-detection', 'human-annotated': 'yes', 'creation-date': '2020-11-19T00:46:58.997946', 'job-name': 'labeling-job/saycam-objects-3-workers-test'}}
# {'source-ref': 's3://interestingsaycam/images/16425-S_20131221_1404_01.mp4-10445.jpg', 'saycam-objects-3-workers-test': {'image_size': [{'width': 640, 'height': 480, 'depth': 3}], 'annotations': [{'class_id': 6, 'top': 45.333333333333314, 'left': 0.6666666666666666, 'height': 434.33333333333337, 'width': 317}, {'class_id': 0, 'top': 179.66666666666669, 'left': 122.33333333333333, 'height': 131.33333333333331, 'width': 150}, {'class_id': 0, 'top': 2, 'left': 53, 'height': 175, 'width': 228}, {'class_id': 14, 'top': 4, 'left': 43, 'height': 188, 'width': 236}]}, 'saycam-objects-3-workers-test-metadata': {'objects': [{'confidence': 0.43}, {'confidence': 0.44}, {'confidence': 0.09}, {'confidence': 0.09}], 'class-map': {'6': 'Person', '0': 'Furniture', '14': 'Plant'}, 'type': 'groundtruth/object-detection', 'human-annotated': 'yes', 'creation-date': '2020-11-19T00:19:09.513055', 'job-name': 'labeling-job/saycam-objects-3-workers-test'}}
# {'source-ref': 's3://interestingsaycam/images/174-A_20130601_0819_03.mp4-4525.jpg', 'saycam-objects-3-workers-test': {'image_size': [{'width': 640, 'height': 480, 'depth': 3}], 'annotations': [{'class_id': 12, 'top': 27, 'left': 16, 'height': 453, 'width': 624}, {'class_id': 10, 'top': 51, 'left': 1, 'height': 429, 'width': 638.5}, {'class_id': 6, 'top': 1, 'left': 315.5, 'height': 474, 'width': 264}, {'class_id': 0, 'top': 1, 'left': 71.5, 'height': 340, 'width': 135.5}]}, 'saycam-objects-3-workers-test-metadata': {'objects': [{'confidence': 0.09}, {'confidence': 0.28}, {'confidence': 0.11}, {'confidence': 0.22}], 'class-map': {'12': 'Other small object', '10': 'Toy (large)', '6': 'Person', '0': 'Furniture'}, 'type': 'groundtruth/object-detection', 'human-annotated': 'yes', 'creation-date': '2020-11-19T01:03:25.936310', 'job-name': 'labeling-job/saycam-objects-3-workers-test'}}
# {'source-ref': 's3://interestingsaycam/images/18115-S_20140320_1703_08.mp4-11330.jpg', 'saycam-objects-3-workers-test': {'image_size': [{'width': 640, 'height': 480, 'depth': 3}], 'annotations': [{'class_id': 0, 'top': 34.666666666666686, 'left': 178.66666666666666, 'height': 192.33333333333331, 'width': 355}, {'class_id': 0, 'top': 12, 'left': 1, 'height': 219, 'width': 74}, {'class_id': 11, 'top': 166, 'left': 532, 'height': 51, 'width': 47}, {'class_id': 5, 'top': 329, 'left': 193.5, 'height': 117.5, 'width': 132}, {'class_id': 5, 'top': 414, 'left': 275, 'height': 66, 'width': 82}, {'class_id': 6, 'top': 335.5, 'left': 230, 'height': 144.5, 'width': 304.5}]}, 'saycam-objects-3-workers-test-metadata': {'objects': [{'confidence': 0.47}, {'confidence': 0.09}, {'confidence': 0.09}, {'confidence': 0.09}, {'confidence': 0.09}, {'confidence': 0.08}], 'class-map': {'0': 'Furniture', '11': 'Toy (small)', '5': 'Clothing', '6': 'Person'}, 'type': 'groundtruth/object-detection', 'human-annotated': 'yes', 'creation-date': '2020-11-19T00:22:16.005185', 'job-name': 'labeling-job/saycam-objects-3-workers-test'}}
# {'source-ref': 's3://interestingsaycam/images/18461-S_20140409_1723_07.mp4-3425.jpg', 'saycam-objects-3-workers-test': {'image_size': [{'width': 640, 'height': 480, 'depth': 3}], 'annotations': [{'class_id': 6, 'top': 176, 'left': 337, 'height': 304, 'width': 303}, {'class_id': 6, 'top': 0, 'left': 406, 'height': 344.33333333333337, 'width': 234}, {'class_id': 11, 'top': 187.5, 'left': 225.5, 'height': 211.5, 'width': 143}, {'class_id': 9, 'top': 188, 'left': 223, 'height': 214, 'width': 142}]}, 'saycam-objects-3-workers-test-metadata': {'objects': [{'confidence': 0.48}, {'confidence': 0.48}, {'confidence': 0.27}, {'confidence': 0.09}], 'class-map': {'6': 'Person', '11': 'Toy (small)', '9': 'Utensils'}, 'type': 'groundtruth/object-detection', 'human-annotated': 'yes', 'creation-date': '2020-11-19T00:15:01.238846', 'job-name': 'labeling-job/saycam-objects-3-workers-test'}}
# {'source-ref': 's3://interestingsaycam/images/19816-S_20140707_2020_03.mp4-14015.jpg', 'saycam-objects-3-workers-test': {'image_size': [{'width': 640, 'height': 480, 'depth': 3}], 'annotations': [{'class_id': 3, 'top': 181, 'left': 412, 'height': 176, 'width': 123}, {'class_id': 9, 'top': 240, 'left': 54, 'height': 53, 'width': 167}, {'class_id': 6, 'top': 311, 'left': 102.5, 'height': 169, 'width': 273}, {'class_id': 6, 'top': 165, 'left': 231.5, 'height': 229.5, 'width': 211.5}, {'class_id': 11, 'top': 101, 'left': 0, 'height': 350, 'width': 532}, {'class_id': 12, 'top': 341, 'left': 525, 'height': 86, 'width': 74}]}, 'saycam-objects-3-workers-test-metadata': {'objects': [{'confidence': 0.09}, {'confidence': 0.09}, {'confidence': 0.27}, {'confidence': 0.28}, {'confidence': 0.09}, {'confidence': 0.09}], 'class-map': {'3': 'Animal (real)', '9': 'Utensils', '6': 'Person', '11': 'Toy (small)', '12': 'Other small object'}, 'type': 'groundtruth/object-detection', 'human-annotated': 'yes', 'creation-date': '2020-11-18T23:56:33.413871', 'job-name': 'labeling-job/saycam-objects-3-workers-test'}}
# {'source-ref': 's3://interestingsaycam/images/20855-S_20140913_2227_10.mp4-5465.jpg', 'saycam-objects-3-workers-test': {'image_size': [{'width': 640, 'height': 480, 'depth': 3}], 'annotations': [{'class_id': 1, 'top': 90.33333333333331, 'left': 92.66666666666667, 'height': 389.6666666666667, 'width': 515.6666666666667}, {'class_id': 14, 'top': 63, 'left': 2, 'height': 167, 'width': 336}, {'class_id': 14, 'top': 388, 'left': 20, 'height': 50, 'width': 49}, {'class_id': 13, 'top': 149, 'left': 1.3333333333333333, 'height': 302, 'width': 157.66666666666666}]}, 'saycam-objects-3-workers-test-metadata': {'objects': [{'confidence': 0.45}, {'confidence': 0.09}, {'confidence': 0.09}, {'confidence': 0.46}], 'class-map': {'1': 'Vehicle (real)', '14': 'Plant', '13': 'Building'}, 'type': 'groundtruth/object-detection', 'human-annotated': 'yes', 'creation-date': '2020-11-18T23:58:29.565138', 'job-name': 'labeling-job/saycam-objects-3-workers-test'}}

# %%
images = {}
annotations = {}
id = 0
classes = {}
taskName = 'saycam-objects-3-workers-test'
taskNameMetadata = 'saycam-objects-3-workers-test-metadata'
for frame in data:
  imagename = frame['source-ref'].split('/')[-1]
  image_url = 'http://langcog.stanford.edu/expts/saycam/frames/' + imagename
  images[id] = {'url': image_url, 'image_size': frame[taskName]['image_size']}
  annotations[id] = frame[taskName]['annotations'] # ignore confidence for now: 'confidence': frame[taskNameMetadata]['objects']}
  for key in frame[taskNameMetadata]['class-map']:
    if key not in classes.keys():
      classes[int(key)] = frame[taskNameMetadata]['class-map'][key]
  id = id + 1

# %% [markdown]
# We now have 3 dataframes.
# - <b>images</b> stores all the image information associated with an arbitrary id
# - <b>annotations</b> stores all the segmentation information associated with the same id as the image
# - <b>classes</b> stores a unique id associated with each class, based on Sagemaker's id assignment

# %%
annotations
# Out:
# {0: [{'class_id': 5, 'height': 148, 'left': 278, 'top': 38, 'width': 53},
#   {'class_id': 5, 'height': 28, 'left': 293, 'top': 176, 'width': 28},
#   {'class_id': 5, 'height': 23, 'left': 273, 'top': 166, 'width': 26},
#   {'class_id': 5, 'height': 60, 'left': 260, 'top': 0, 'width': 105},
#   {'class_id': 6,
#    'height': 201.66666666666663,
#    'left': 264,
#    'top': 2.6666666666666856,
#    'width': 84.66666666666669},
#   {'class_id': 0,
#    'height': 343,
#    'left': 477.6666666666667,
#    'top': 136.33333333333331,
#    'width': 161.66666666666669},
#   {'class_id': 13, 'height': 369, 'left': 5, 'top': 106, 'width': 556},
#   {'class_id': 12, 'height': 301, 'left': 492, 'top': 173, 'width': 148}],
#  1: [{'class_id': 12,
#    'height': 371.5,
#    'left': 3.5,
#    'top': 105,
#    'width': 330.5},
#   {'class_id': 12, 'height': 93, 'left': 63, 'top': 314, 'width': 100},
#   {'class_id': 13, 'height': 477, 'left': 2, 'top': 2, 'width': 636}],
#  2: [{'class_id': 0,
#    'height': 131.33333333333334,
#    'left': 24,
#    'top': 308.66666666666663,
#    'width': 491.66666666666663},
#   {'class_id': 6,
#    'height': 374,
#    'left': 177.66666666666666,
#    'top': 2,
#    'width': 404},
#   {'class_id': 8, 'height': 68, 'left': 196, 'top': 296, 'width': 50},
#   {'class_id': 9, 'height': 121, 'left': 16, 'top': 359, 'width': 624},
#   {'class_id': 12, 'height': 87, 'left': 114, 'top': 230, 'width': 61}],
#  3: [{'class_id': 6,
#    'height': 434.33333333333337,
#    'left': 0.6666666666666666,
#    'top': 45.333333333333314,
#    'width': 317},
#   {'class_id': 0,
#    'height': 131.33333333333331,
#    'left': 122.33333333333333,
#    'top': 179.66666666666669,
#    'width': 150},
#   {'class_id': 0, 'height': 175, 'left': 53, 'top': 2, 'width': 228},
#   {'class_id': 14, 'height': 188, 'left': 43, 'top': 4, 'width': 236}],
#  4: [{'class_id': 12, 'height': 453, 'left': 16, 'top': 27, 'width': 624},
#   {'class_id': 10, 'height': 429, 'left': 1, 'top': 51, 'width': 638.5},
#   {'class_id': 6, 'height': 474, 'left': 315.5, 'top': 1, 'width': 264},
#   {'class_id': 0, 'height': 340, 'left': 71.5, 'top': 1, 'width': 135.5}],
#  5: [{'class_id': 0,
#    'height': 192.33333333333331,
#    'left': 178.66666666666666,
#    'top': 34.666666666666686,
#    'width': 355},
#   {'class_id': 0, 'height': 219, 'left': 1, 'top': 12, 'width': 74},
#   {'class_id': 11, 'height': 51, 'left': 532, 'top': 166, 'width': 47},
#   {'class_id': 5, 'height': 117.5, 'left': 193.5, 'top': 329, 'width': 132},
#   {'class_id': 5, 'height': 66, 'left': 275, 'top': 414, 'width': 82},
#   {'class_id': 6, 'height': 144.5, 'left': 230, 'top': 335.5, 'width': 304.5}],
#  6: [{'class_id': 6, 'height': 304, 'left': 337, 'top': 176, 'width': 303},
#   {'class_id': 6,
#    'height': 344.33333333333337,
#    'left': 406,
#    'top': 0,
#    'width': 234},
#   {'class_id': 11, 'height': 211.5, 'left': 225.5, 'top': 187.5, 'width': 143},
#   {'class_id': 9, 'height': 214, 'left': 223, 'top': 188, 'width': 142}],
#  7: [{'class_id': 3, 'height': 176, 'left': 412, 'top': 181, 'width': 123},
#   {'class_id': 9, 'height': 53, 'left': 54, 'top': 240, 'width': 167},
#   {'class_id': 6, 'height': 169, 'left': 102.5, 'top': 311, 'width': 273},
#   {'class_id': 6, 'height': 229.5, 'left': 231.5, 'top': 165, 'width': 211.5},
#   {'class_id': 11, 'height': 350, 'left': 0, 'top': 101, 'width': 532},
#   {'class_id': 12, 'height': 86, 'left': 525, 'top': 341, 'width': 74}],
#  8: [{'class_id': 1,
#    'height': 389.6666666666667,
#    'left': 92.66666666666667,
#    'top': 90.33333333333331,
#    'width': 515.6666666666667},
#   {'class_id': 14, 'height': 167, 'left': 2, 'top': 63, 'width': 336},
#   {'class_id': 14, 'height': 50, 'left': 20, 'top': 388, 'width': 49},
#   {'class_id': 13,
#    'height': 302,
#    'left': 1.3333333333333333,
#    'top': 149,
#    'width': 157.66666666666666}]}

# %%
classes
# Out:
# {0: 'Furniture',
#  1: 'Vehicle (real)',
#  3: 'Animal (real)',
#  5: 'Clothing',
#  6: 'Person',
#  8: 'Food',
#  9: 'Utensils',
#  10: 'Toy (large)',
#  11: 'Toy (small)',
#  12: 'Other small object',
#  13: 'Building',
#  14: 'Plant'}

# %% [markdown]
# # Convert JSONs to COCO JSON format

# %%
import os
def get_filename_as_int(filename):
    try:
        filename = os.path.basename(filename)
        filename = filename.split('/')[-1].split('.')[0].split('-')[0]
        return filename
    except:
        raise ValueError("Filename %s is supposed to be an integer." % (filename))

# %%
# show image information
images[0]['image_size'][0]
# Out:
# {'depth': 3, 'height': 480, 'width': 640}

# %%
# conversion function taking dataframes and writing to file in coco json format
def convert(categories, images, annotations, json_file):
  json_dict = {"images": [], "type": "instances", "annotations": [], "categories": []}
  bnd_id = 1      # bounding box id
  IDsSeen=[]
  for id in annotations.keys():
    im = images[id]
    filename = im['url']
    image_id = get_filename_as_int(filename) 
    if image_id not in IDsSeen:
      width = im['image_size'][0]['width']
      height = im['image_size'][0]['height']
      image = {
          "file_name": filename,
          "height": height,
          "width": width,
          "id": image_id}
      json_dict["images"].append(image)
      IDsSeen.append(image_id)
    for an in annotations[id]:
      category_id = an['class_id']
      xmin = an['left']
      ymin = an['top']
      width = an['width']
      height = an['height']
      image_id = get_filename_as_int(filename)
      ann = {
          "area": width * height,
          "iscrowd": 0,
          "image_id": image_id,
          "bbox": [xmin, ymin, width, height],
          "category_id": category_id,
          "id": bnd_id,
          "ignore": 0,
          "segmentation": [],
      }
      json_dict["annotations"].append(ann)
      bnd_id = bnd_id + 1
  for cid, cate in categories.items():
    cat = {"supercategory": "none", "id": cid, "name": cate}
    json_dict["categories"].append(cat)

  os.makedirs(os.path.dirname(json_file), exist_ok=True)
  json_fp = open(json_file, "w")
  json_str = json.dumps(json_dict)
  json_fp.write(json_str)
  json_fp.close()

# %%
convert(classes, images, annotations, "./output.json")

# %% [markdown]
# # Load COCO JSON

# %% [markdown]
# # Dump

# %%
labels = loadObjList('https://raw.githubusercontent.com/brialorelle/headcam-objects/master/data/category_lists/categories.txt')
with open('categories.txt', 'w') as f:
    for item in labels:
        f.write("%s\n" % item)

# %%
import json
from pprint import pprint

with open('output.manifest') as f:
    data = json.loads("[" + 
        f.read().replace("}\n{", "},\n{") + 
    "]")

    print(data)
